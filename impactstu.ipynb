# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#loading the dataset
df = pd.read_csv("./data/ai_impact_student_performance_dataset.csv")
df.head(20)
# Out:
#     student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 0            1   20  Female    1st Year                  2.5        1
# 1            2   17    Male        12th                  3.4        1
# 2            3   24    Male    3rd Year                  0.8        0
# 3            4   21  Female        12th                  4.4        0
# 4            5   18   Other    3rd Year                  3.5        1
# 5            6   20    Male    1st Year                  5.1        1
# 6            7   23  Female    1st Year                  2.0        1
# 7            8   16    Male    3rd Year                  5.5        0
# 8            9   20  Female        10th                  6.0        1
# 9           10   24  Female    1st Year                  5.6        0
# 10          11   24  Female        10th                  4.8        1
# 11          12   21    Male        10th                  5.0        0
# ...

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   student_id                       8000 non-null   int64
#  1   age                              8000 non-null   int64
#  2   gender                           8000 non-null   object
#  3   grade_level                      8000 non-null   object
#  4   study_hours_per_day              8000 non-null   float64
#  5   uses_ai                          8000 non-null   int64
#  6   ai_usage_time_minutes            8000 non-null   int64
#  7   ai_tools_used                    6638 non-null   object
#  8   ai_usage_purpose                 6654 non-null   object
#  9   ai_dependency_score              8000 non-null   int64
#  10  ai_generated_content_percentage  8000 non-null   int64
#  11  ai_prompts_per_week              8000 non-null   int64
# ...

# %%
df.dtypes
# Out:
# student_id                           int64
# age                                  int64
# gender                              object
# grade_level                         object
# study_hours_per_day                float64
# uses_ai                              int64
# ai_usage_time_minutes                int64
# ai_tools_used                       object
# ai_usage_purpose                    object
# ai_dependency_score                  int64
# ai_generated_content_percentage      int64
# ai_prompts_per_week                  int64
# ai_ethics_score                      int64
# last_exam_score                      int64
# assignment_scores_avg              float64
# attendance_percentage              float64
# concept_understanding_score          int64
# study_consistency_index            float64
# improvement_rate                   float64
# sleep_hours                        float64
# social_media_hours                 float64
# tutoring_hours                     float64
# ...

# %%
df.isnull().sum()
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'grade_level', 'study_hours_per_day',
#        'uses_ai', 'ai_usage_time_minutes', 'ai_tools_used', 'ai_usage_purpose',
#        'ai_dependency_score', 'ai_generated_content_percentage',
#        'ai_prompts_per_week', 'ai_ethics_score', 'last_exam_score',
#        'assignment_scores_avg', 'attendance_percentage',
#        'concept_understanding_score', 'study_consistency_index',
#        'improvement_rate', 'sleep_hours', 'social_media_hours',
#        'tutoring_hours', 'class_participation_score', 'final_score', 'passed',
#        'performance_category'],
#       dtype='object')

# %%
df.drop(columns=['grade_level', 'ai_tools_used', 'ai_usage_purpose',  'ai_dependency_score', 'ai_generated_content_percentage',
       'ai_prompts_per_week', 'ai_ethics_score', 'attendance_percentage',
       'concept_understanding_score', 'study_consistency_index',
       'improvement_rate', 'sleep_hours', 'social_media_hours',
       'tutoring_hours', 'class_participation_score', 'passed',
       'performance_category'], inplace=True)

# %%
df.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# study_hours_per_day      0
# uses_ai                  0
# ai_usage_time_minutes    0
# last_exam_score          0
# assignment_scores_avg    0
# final_score              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             8000 non-null   int64
#  1   age                    8000 non-null   int64
#  2   gender                 8000 non-null   object
#  3   study_hours_per_day    8000 non-null   float64
#  4   uses_ai                8000 non-null   int64
#  5   ai_usage_time_minutes  8000 non-null   int64
#  6   last_exam_score        8000 non-null   int64
#  7   assignment_scores_avg  8000 non-null   float64
#  8   final_score            8000 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 562.6+ KB

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (8000, 9)

# %%
df.to_csv("./data/cleaned_ai_impact_student_performance_dataset.csv", index=False)

# %%
import numpy as np

# %%
#correlation between AI usage time and final score
df[["study_hours_per_day", "final_score"]].corr()
# Out:
#                      study_hours_per_day  final_score
# study_hours_per_day             1.000000     0.015798
# final_score                     0.015798     1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.regplot(x="study_hours_per_day", y="final_score", data=df)
plt.ylim(0, )
# Out:
# (0.0, 99.955)

# %%
df[["ai_usage_time_minutes", "final_score"]].corr()
# Out:
#                        ai_usage_time_minutes  final_score
# ai_usage_time_minutes                1.00000     -0.00161
# final_score                         -0.00161      1.00000

# %%
sns.regplot(x="ai_usage_time_minutes", y="final_score", data=df)
plt.ylim(0, )
# Out:
# (0.0, 99.955)

# %%
df[["study_hours_per_day", "uses_ai", "ai_usage_time_minutes",
    "last_exam_score", "assignment_scores_avg", "final_score"]].corr()
# Out:
#                        study_hours_per_day   uses_ai  ai_usage_time_minutes  \
# study_hours_per_day               1.000000 -0.009835               0.002130
# uses_ai                          -0.009835  1.000000              -0.008734
# ai_usage_time_minutes             0.002130 -0.008734               1.000000
# last_exam_score                   0.009136  0.004980              -0.015640
# assignment_scores_avg            -0.007500 -0.011901               0.009731
# final_score                       0.015798 -0.001628              -0.001610
#
#                        last_exam_score  assignment_scores_avg  final_score
# study_hours_per_day           0.009136              -0.007500     0.015798
# uses_ai                       0.004980              -0.011901    -0.001628
# ai_usage_time_minutes        -0.015640               0.009731    -0.001610
# last_exam_score               1.000000               0.006272     0.681675
# ...

# %% [markdown]
# Working on the whole dataset

# %%
#loading the dataset

data = pd.read_csv("./data/ai_impact_student_performance_dataset.csv")
data
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 0              1   20  Female    1st Year                  2.5        1
# 1              2   17    Male        12th                  3.4        1
# 2              3   24    Male    3rd Year                  0.8        0
# 3              4   21  Female        12th                  4.4        0
# 4              5   18   Other    3rd Year                  3.5        1
# ...          ...  ...     ...         ...                  ...      ...
# 7995        7996   23    Male    3rd Year                  3.0        0
# 7996        7997   21   Other    1st Year                  3.3        0
# 7997        7998   24    Male    3rd Year                  1.6        0
# 7998        7999   22  Female    2nd Year                  5.5        0
# 7999        8000   15    Male        12th                  4.6        0
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# ...

# %%
data.isnull().sum()
# Out:
# student_id                            0
# age                                   0
# gender                                0
# grade_level                           0
# study_hours_per_day                   0
# uses_ai                               0
# ai_usage_time_minutes                 0
# ai_tools_used                      1362
# ai_usage_purpose                   1346
# ai_dependency_score                   0
# ai_generated_content_percentage       0
# ai_prompts_per_week                   0
# ai_ethics_score                       0
# last_exam_score                       0
# assignment_scores_avg                 0
# attendance_percentage                 0
# concept_understanding_score           0
# study_consistency_index               0
# improvement_rate                      0
# sleep_hours                           0
# social_media_hours                    0
# tutoring_hours                        0
# class_participation_score             0
# ...

# %%
mode_ai = data["ai_tools_used"].mode()
mode_ai
# Out:
# 0    ChatGPT+Gemini
# Name: ai_tools_used, dtype: object

# %%
data["ai_tools_used"].replace(np.nan, "ChatGPT+Gemini", inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_26348\3996561436.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["ai_tools_used"].replace(np.nan, "ChatGPT+Gemini", inplace=True)

# %%
mode_use_ai = data["ai_usage_purpose"].mode()
mode_use_ai
# Out:
# 0    Exam Prep
# Name: ai_usage_purpose, dtype: object

# %%
data["ai_usage_purpose"].replace(np.nan, "Exam Prep", inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_26348\4049367446.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["ai_usage_purpose"].replace(np.nan, "Exam Prep", inplace=True)

# %%
data
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 0              1   20  Female    1st Year                  2.5        1
# 1              2   17    Male        12th                  3.4        1
# 2              3   24    Male    3rd Year                  0.8        0
# 3              4   21  Female        12th                  4.4        0
# 4              5   18   Other    3rd Year                  3.5        1
# ...          ...  ...     ...         ...                  ...      ...
# 7995        7996   23    Male    3rd Year                  3.0        0
# 7996        7997   21   Other    1st Year                  3.3        0
# 7997        7998   24    Male    3rd Year                  1.6        0
# 7998        7999   22  Female    2nd Year                  5.5        0
# 7999        8000   15    Male        12th                  4.6        0
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# ...

# %%
data.isnull().sum()
# Out:
# student_id                         0
# age                                0
# gender                             0
# grade_level                        0
# study_hours_per_day                0
# uses_ai                            0
# ai_usage_time_minutes              0
# ai_tools_used                      0
# ai_usage_purpose                   0
# ai_dependency_score                0
# ai_generated_content_percentage    0
# ai_prompts_per_week                0
# ai_ethics_score                    0
# last_exam_score                    0
# assignment_scores_avg              0
# attendance_percentage              0
# concept_understanding_score        0
# study_consistency_index            0
# improvement_rate                   0
# sleep_hours                        0
# social_media_hours                 0
# tutoring_hours                     0
# class_participation_score          0
# final_score                        0
# passed                             0
# ...

# %%
num_data=data.select_dtypes(include=['number'])
corr_pairs = num_data.corr().unstack()
corr_pairs[corr_pairs != 1.0].sort_values(ascending=False)
corr_pairs
# Out:
# student_id  student_id                   1.000000
#             age                          0.016347
#             study_hours_per_day         -0.018194
#             uses_ai                      0.020702
#             ai_usage_time_minutes        0.013013
#                                            ...
# passed      social_media_hours           0.006983
#             tutoring_hours              -0.010001
#             class_participation_score    0.010028
#             final_score                  0.592637
#             passed                       1.000000
# Length: 441, dtype: float64

# %%
data.corr(numeric_only=True)["final_score"].sort_values(ascending=False)
# Out:
# final_score                        1.000000
# last_exam_score                    0.681675
# passed                             0.592637
# assignment_scores_avg              0.454554
# concept_understanding_score        0.423874
# study_hours_per_day                0.015798
# ai_dependency_score                0.014077
# ai_ethics_score                    0.013269
# age                                0.007615
# social_media_hours                 0.004099
# student_id                         0.003917
# class_participation_score          0.003523
# improvement_rate                  -0.001549
# ai_usage_time_minutes             -0.001610
# uses_ai                           -0.001628
# attendance_percentage             -0.005182
# sleep_hours                       -0.005785
# tutoring_hours                    -0.008564
# ai_prompts_per_week               -0.010148
# study_consistency_index           -0.014126
# ai_generated_content_percentage   -0.096552
# ...

# %%
data
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 0              1   20  Female    1st Year                  2.5        1
# 1              2   17    Male        12th                  3.4        1
# 2              3   24    Male    3rd Year                  0.8        0
# 3              4   21  Female        12th                  4.4        0
# 4              5   18   Other    3rd Year                  3.5        1
# ...          ...  ...     ...         ...                  ...      ...
# 7995        7996   23    Male    3rd Year                  3.0        0
# 7996        7997   21   Other    1st Year                  3.3        0
# 7997        7998   24    Male    3rd Year                  1.6        0
# 7998        7999   22  Female    2nd Year                  5.5        0
# 7999        8000   15    Male        12th                  4.6        0
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# ...

# %%
data[data['final_score'] == 60]
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 308          309   16    Male        11th                  6.0        1
# 564          565   23    Male    3rd Year                  2.6        0
# 1976        1977   21   Other        10th                  5.6        1
# 2186        2187   17  Female    1st Year                  2.3        1
# 2521        2522   15    Male        12th                  3.3        1
# 2634        2635   21   Other        12th                  1.7        0
# 2926        2927   24    Male        11th                  5.0        0
# 3297        3298   24  Female    2nd Year                  5.3        0
# 3362        3363   23  Female        12th                  4.4        1
# 3519        3520   15   Other        10th                  4.6        1
# 3646        3647   17  Female    2nd Year                  4.3        1
# 3776        3777   16    Male        12th                  3.4        1
# ...

# %%
data.groupby("ai_tools_used")["final_score"].mean().reset_index()
# Out:
#     ai_tools_used  final_score
# 0         ChatGPT    56.732658
# 1  ChatGPT+Gemini    56.806592
# 2          Claude    56.496794
# 3         Copilot    56.822006
# 4          Gemini    57.209077
